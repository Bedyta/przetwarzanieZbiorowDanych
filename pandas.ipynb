# %%
print("hi")
# Out:
# hi

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # pandas

# %%
movie_path = 'https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook/master/data/movie.csv'
movie = pd.read_csv(movie_path)
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# # dataframe

# %%
columns = movie.columns
index = movie.index
data = movie.values

# %%
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
type(columns)
# Out:
# pandas.core.indexes.base.Index

# %%
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
data
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
X = mp.random.randn(10, 10)
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 X = mp.random.randn(10, 10)
#       2 X
#
# NameError: name 'mp' is not defined

# %%
X= np.random,randn(10, 10)
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 X= np.random,randn(10, 10)
#       2 X
#
# NameError: name 'randn' is not defined

# %%
X3 = np.random.randn(3, 3)
X3
# Out:
# array([[-0.79303971, -0.52982453, -0.57296636],
#        [ 0.9003418 ,  1.21719895,  0.8377715 ],
#        [ 1.67036117, -0.70859486, -0.52019703]])

# %%
df = pd.DataFrame(X3, columns=['col_1', 'col_2', 'col_3'], index=['idx_a', 'idx_3', 'idx_4'])
df
# Out:
#           col_1     col_2     col_3
# idx_a -0.793040 -0.529825 -0.572966
# idx_3  0.900342  1.217199  0.837772
# idx_4  1.670361 -0.708595 -0.520197

# %%
df_1 = pd.DataFrame({
    'col_4': [1, 2, 3],
    'col_5': [3, 5, 8]
})
df_1
# Out:
#    col_4  col_5
# 0      1      3
# 1      2      5
# 2      3      8

# %%
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# # series

# %%
movie.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# ...

# %%
# !mkdir data

# %%
movie.to_csv('data/movie.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 movie.to_csv('data/movie.csv')
#
# NameError: name 'movie' is not defined

# %%
movie.to_csv('data/movie.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 movie.to_csv('data/movie.csv')
#
# NameError: name 'movie' is not defined

# %%
movie_path = 'https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook/master/data/movie.csv'
movie = pd.read_csv(movie_path)
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie.to_csv('data/movie.csv')

# %% [markdown]
# # index

# %%
movie = pd.read_csv('data/movie.csv', sep=',', index_col='movie_title')
movie.head()
# Out:
#                                             Unnamed: 0  color  \
# movie_title
# Avatar                                               0  Color
# Pirates of the Caribbean: At World's End             1  Color
# Spectre                                              2  Color
# The Dark Knight Rises                                3  Color
# Star Wars: Episode VII - The Force Awakens           4    NaN
#
#                                                 director_name  \
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# ...

# %% [markdown]
# # sort

# %%
movie.sort_values('duration')
# Out:
#                                       Unnamed: 0  color     director_name  \
# movie_title
# The Touch                                   2316  Color        Jane Clark
# Shaun the Sheep                             1930  Color               NaN
# Robot Chicken                               3997  Color               NaN
# Vessel                                      4564  Color       Clark Baker
# Wal-Mart: The High Cost of Low Price        4342  Color  Robert Greenwald
# ...                                          ...    ...               ...
# Wolf Creek                                  4416  Color               NaN
# Karachi se Lahore                           4502  Color      Wajahat Rauf
# Destiny                                     4580  Color   Joseph Kosinski
# Romantic Schemer                            4825  Color         Valentine
# The Naked Ape                               4863  Color    Daniel Mellitz
#
# ...

# %% [markdown]
# # column and index renaming

# %%
movie.head()
# Out:
#                                             Unnamed: 0  color  \
# movie_title
# Avatar                                               0  Color
# Pirates of the Caribbean: At World's End             1  Color
# Spectre                                              2  Color
# The Dark Knight Rises                                3  Color
# Star Wars: Episode VII - The Force Awakens           4    NaN
#
#                                                 director_name  \
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# ...

# %%
movie = movie.set_index('movie_title')
movie.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 movie = movie.set_index('movie_title')
#       2 movie.head()
#
# File ~\data\przetwarzanie_zbiorow_danych\przetwarzanieZbiorowDanych\venv_edyta\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\data\przetwarzanie_zbiorow_danych\przetwarzanieZbiorowDanych\venv_edyta\lib\site-packages\pandas\core\frame.py:5500, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5497                 missing.append(col)
# ...

# %%
col_name = {'color': 'kolor': 'director_name': 'rezyser'}
movie_renamed = movie.rename(columns=col_name)
movie_renamed.head()
# Out:
#   Input In [18]
#     col_name = {'color': 'kolor': 'director_name': 'rezyser'}
#                                 ^
# SyntaxError: invalid syntax

# %%
movie_columns = movie.columns.tolist()
movie_columns
# Out:
# ['Unnamed: 0',
#  'color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
movie_columns[1] = 'kolor'
movie_columns[] = 'rezyser'
# Out:
#   Input In [22]
#     movie_columns[] = 'rezyser'
#                   ^
# SyntaxError: invalid syntax

# %%
movie_columns[1] = 'kolor'
movie_columns[2] = 'rezyser'

# %%
movie_columns
# Out:
# ['Unnamed: 0',
#  'kolor',
#  'rezyser',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']
